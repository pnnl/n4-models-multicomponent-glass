# %% [markdown]
# # Heteroskedastic DNN Training

# %%
import tensorflow as tf
from tensorflow import keras    
from sklearn.preprocessing import StandardScaler, OrdinalEncoder
from scipy import stats
import pandas as pd
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import root_mean_squared_error, r2_score
from ML_Models.heteroscedastic_DNN import HeteroscedasticDNN
import numpy as np
import os
import csv
import random

# %% [markdown]
# ##  Preprocessing

# %%
n4_df = pd.read_excel("../../data/boron_coord_final.xlsx")
n4_df = n4_df.dropna(subset='%')

cooling_order = [['Slow cooled', 'Air quench', 'Water quench', 'Fast quench']]
enc = OrdinalEncoder(categories=cooling_order)
n4_df['Ordinal cooling'] = enc.fit_transform(n4_df[['Cooling rate']])

# %%
other = ['Cr2O3', 'HfO2', 'PbO', 'UO3', 'Y2O3','ZrO2','Fe2O3',
         'P2O5', 'TiO2', 'CoO','SrO','Cs2O','Bi2O3','BaO','SO3','La2O3']
oxEl = ['Al2O3','B2O3','CaO','K2O','Li2O','MgO','Na2O','SiO2',
 'ZnO','Rb2O']

# %%
n4_df['other'] = n4_df[['Cr2O3', 'HfO2', 'PbO', 'UO3', 'Y2O3','ZrO2','Fe2O3','P2O5', 'TiO2', 'CoO','SrO','Cs2O','Bi2O3','BaO','SO3','La2O3']].sum(axis=1)
class_cols = oxEl + ['other', 'Ordinal cooling']
X = n4_df[ class_cols ].fillna(0)
y = n4_df['%']

# %%
X_train_df, X_test_df, y_train_df, y_test_df = train_test_split(X, y, test_size=0.20, random_state=42)

X_train = X_train_df.to_numpy()
X_test = X_test_df.to_numpy()

y_train = y_train_df.to_numpy()
y_test = y_test_df.to_numpy()

# %% [markdown]
# ## KFold Cross Validation

# %%
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# %%
filename = 'dnn_architecture_tuning.csv'

if not os.path.exists(f'./{filename}'):
    with open(filename, 'w', newline='') as file:
        writer = csv.DictWriter(file, fieldnames = ['arch', 'r2', 'rmse'])
        writer.writeheader()

    archs = [[8,8,8,8], [32,32,32,32], [32, 200, 200, 256]]
    for arch in archs: 
        r2 = []
        rmse = []
      
        for fold_idx, (train_index, test_index) in enumerate(kf.split(X_train, y_train)):
            X_ktrain = X_train[train_index]
            X_ktest = X_train[test_index]

            y_ktrain = y_train[train_index]
            y_ktest = y_train[test_index]
           
            
            model = HeteroscedasticDNN(input_dim=X_ktrain.shape[1], output_dim=y_ktrain.shape[1], hidden_layers=arch)
            history = model.fit(X_ktrain, y_ktrain)

            y_pred, var_pred = model.predict_with_uncertainty(X_ktest)
            y_pred = np.maximum(y_pred, 0)
            
            r2_k = r2_score(y_ktest, y_pred)
            rmse_k = root_mean_squared_error(y_ktest, y_pred)

            r2.append(r2_k)
            rmse.append(rmse_k)

            dict = {'arch': arch,
            'r2': r2_k,
            'rmse': rmse_k}

            with open(filename, 'a', newline='') as file:
                writer = csv.DictWriter(file, fieldnames = dict.keys())
                writer.writerow(dict)

        dict = {'arch': f'{arch}_average',
                'r2': sum(r2)/len(r2),
                'rmse': sum(rmse)/len(rmse)}
        
        with open(filename, 'a', newline='') as file:
            writer = csv.DictWriter(file, fieldnames = dict.keys())
            writer.writerow(dict)

# %%
# Define the filename for architecture tuning results
filename = 'dnn_architecture_tuning.csv'

print("\nSELECTING BEST ARCHITECTURE FROM TUNING RESULTS:")

try:
    # Step 1: Read the CSV file
    df = pd.read_csv(filename)

    # Step 2: Filter rows where architectures are NOT averages (you can include averages or exclude them)
    df_filtered = df[df["arch"].astype(str).str.contains('average')]
    
    # Step 3: Define the performance metric for selecting the best architecture
    best_row = df_filtered.loc[df_filtered['r2'].idxmax()]  # Choose row with the highest accuracy
    # Alternatively, minimize RMSE:
    # best_row = df_filtered.loc[df_filtered['rmse'].idxmin()] 
    
    # Save best architecture for the model
    best_architecture = best_row['arch'].replace('_average','')  # Extract the architecture
    
    # Extract performance metrics
    best_r2 = best_row['r2']
    best_rmse = best_row['rmse']
    
    # Print the best architecture and performance metrics
    print("Best Architecture:")
    print(f"  Architecture: {best_architecture}")
    print("Performance:")
    print(f"  R²: {best_r2}")
    print(f"  RMSE: {best_rmse}")

except Exception as e:
    # Handle errors gracefully
    print(f"Error processing architecture tuning results: {str(e)}")
# Out:
# SELECTING BEST ARCHITECTURE FROM TUNING RESULTS:
# Best Architecture:
#   Architecture: [32, 32, 32, 32]
# Performance:
#   R²: 0.8547109634026171
#   RMSE: 8.109945296972263

# %% [markdown]
# ## Train Model

# %%
# Initialize and train model
model = HeteroscedasticDNN(input_dim=12, output_dim=1, hidden_layers=[32,32,32,32])
history = model.fit(X_train, y_train.reshape(-1,1))
# Out:
# Epoch 1/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5066 - learning_rate: 0.0010
# Epoch 2/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5011 - learning_rate: 0.0010
# Epoch 3/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4993 - learning_rate: 0.0010
# Epoch 4/5000
#  1/21 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.4549
# c:\Users\curr666\AppData\Local\miniconda3\envs\nepheline\lib\site-packages\keras\src\callbacks\early_stopping.py:99: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
#   current = self.get_monitor_value(logs)
# c:\Users\curr666\AppData\Local\miniconda3\envs\nepheline\lib\site-packages\keras\src\callbacks\callback_list.py:171: UserWarning: Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,learning_rate.
#   callback.on_epoch_end(epoch, logs)
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4980 - learning_rate: 0.0010
# Epoch 5/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4960 - learning_rate: 0.0010
# Epoch 6/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4929 - learning_rate: 0.0010
# Epoch 7/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4877 - learning_rate: 0.0010
# Epoch 8/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4784 - learning_rate: 0.0010
# Epoch 9/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4607 - learning_rate: 0.0010
# Epoch 10/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4263 - learning_rate: 0.0010
# Epoch 11/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3629 - learning_rate: 0.0010
# Epoch 12/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2712 - learning_rate: 0.0010
# Epoch 13/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1980 - learning_rate: 0.0010
# Epoch 14/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1677 - learning_rate: 0.0010
# Epoch 15/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1484 - learning_rate: 0.0010
# Epoch 16/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1318 - learning_rate: 0.0010
# Epoch 17/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1190 - learning_rate: 0.0010
# Epoch 18/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1095 - learning_rate: 0.0010
# Epoch 19/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1019 - learning_rate: 0.0010
# Epoch 20/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0953 - learning_rate: 0.0010
# Epoch 21/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0891 - learning_rate: 0.0010
# Epoch 22/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0830 - learning_rate: 0.0010
# Epoch 23/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0769 - learning_rate: 0.0010
# Epoch 24/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0707 - learning_rate: 0.0010
# Epoch 25/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0646 - learning_rate: 0.0010
# Epoch 26/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0585 - learning_rate: 0.0010
# Epoch 27/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0525 - learning_rate: 0.0010
# Epoch 28/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0467 - learning_rate: 0.0010
# Epoch 29/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0410 - learning_rate: 0.0010
# Epoch 30/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0355 - learning_rate: 0.0010
# Epoch 31/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0301 - learning_rate: 0.0010
# Epoch 32/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0250 - learning_rate: 0.0010
# Epoch 33/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0200 - learning_rate: 0.0010
# Epoch 34/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0153 - learning_rate: 0.0010
# Epoch 35/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0107 - learning_rate: 0.0010
# Epoch 36/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0064 - learning_rate: 0.0010
# Epoch 37/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022 - learning_rate: 0.0010
# Epoch 38/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.0018 - learning_rate: 0.0010
# Epoch 39/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.0057 - learning_rate: 0.0010
# Epoch 40/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.0093 - learning_rate: 0.0010
# Epoch 41/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.0129 - learning_rate: 0.0010
# Epoch 42/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.0163 - learning_rate: 0.0010
# Epoch 43/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.0196 - learning_rate: 0.0010
# Epoch 44/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.0228 - learning_rate: 0.0010
# Epoch 45/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.0259 - learning_rate: 0.0010
# Epoch 46/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.0290 - learning_rate: 0.0010
# Epoch 47/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.0320 - learning_rate: 0.0010
# Epoch 48/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.0349 - learning_rate: 0.0010
# Epoch 49/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.0379 - learning_rate: 0.0010
# Epoch 50/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.0408 - learning_rate: 0.0010
# Epoch 51/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.0438 - learning_rate: 0.0010
# Epoch 52/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.0467 - learning_rate: 0.0010
# Epoch 53/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.0497 - learning_rate: 0.0010
# Epoch 54/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.0527 - learning_rate: 0.0010
# Epoch 55/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.0557 - learning_rate: 0.0010
# Epoch 56/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.0588 - learning_rate: 0.0010
# Epoch 57/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.0618 - learning_rate: 0.0010
# Epoch 58/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.0649 - learning_rate: 0.0010
# Epoch 59/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.0681 - learning_rate: 0.0010
# Epoch 60/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: -0.0712 - learning_rate: 0.0010
# Epoch 61/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.0744 - learning_rate: 0.0010
# Epoch 62/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: -0.0776 - learning_rate: 0.0010
# Epoch 63/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.0809 - learning_rate: 0.0010
# Epoch 64/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.0841 - learning_rate: 0.0010
# Epoch 65/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.0874 - learning_rate: 0.0010
# Epoch 66/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.0906 - learning_rate: 0.0010
# Epoch 67/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.0939 - learning_rate: 0.0010
# Epoch 68/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.0971 - learning_rate: 0.0010
# Epoch 69/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.1004 - learning_rate: 0.0010
# Epoch 70/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.1036 - learning_rate: 0.0010
# Epoch 71/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.1068 - learning_rate: 0.0010
# Epoch 72/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.1100 - learning_rate: 0.0010
# Epoch 73/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.1132 - learning_rate: 0.0010
# Epoch 74/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.1163 - learning_rate: 0.0010
# Epoch 75/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.1194 - learning_rate: 0.0010
# Epoch 76/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.1225 - learning_rate: 0.0010
# Epoch 77/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.1255 - learning_rate: 0.0010
# Epoch 78/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.1285 - learning_rate: 0.0010
# Epoch 79/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.1314 - learning_rate: 0.0010
# Epoch 80/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.1343 - learning_rate: 0.0010
# Epoch 81/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.1372 - learning_rate: 0.0010
# Epoch 82/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.1400 - learning_rate: 0.0010
# Epoch 83/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.1428 - learning_rate: 0.0010
# Epoch 84/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.1455 - learning_rate: 0.0010
# Epoch 85/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.1482 - learning_rate: 0.0010
# Epoch 86/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.1508 - learning_rate: 0.0010
# Epoch 87/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.1534 - learning_rate: 0.0010
# Epoch 88/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.1560 - learning_rate: 0.0010
# Epoch 89/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.1585 - learning_rate: 0.0010
# Epoch 90/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.1610 - learning_rate: 0.0010
# Epoch 91/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.1634 - learning_rate: 0.0010
# Epoch 92/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.1658 - learning_rate: 0.0010
# Epoch 93/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: -0.1682 - learning_rate: 0.0010
# Epoch 94/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -0.1705 - learning_rate: 0.0010
# Epoch 95/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -0.1729 - learning_rate: 0.0010
# Epoch 96/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.1752 - learning_rate: 0.0010
# Epoch 97/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.1774 - learning_rate: 0.0010
# Epoch 98/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.1796 - learning_rate: 0.0010
# Epoch 99/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.1818 - learning_rate: 0.0010
# Epoch 100/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: -0.1840 - learning_rate: 0.0010
# Epoch 101/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: -0.1862 - learning_rate: 0.0010
# Epoch 102/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.1883 - learning_rate: 0.0010
# Epoch 103/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.1904 - learning_rate: 0.0010
# Epoch 104/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.1925 - learning_rate: 0.0010
# Epoch 105/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.1945 - learning_rate: 0.0010
# Epoch 106/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.1965 - learning_rate: 0.0010
# Epoch 107/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.1985 - learning_rate: 0.0010
# Epoch 108/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.2005 - learning_rate: 0.0010
# Epoch 109/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.2025 - learning_rate: 0.0010
# Epoch 110/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.2044 - learning_rate: 0.0010
# Epoch 111/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.2063 - learning_rate: 0.0010
# Epoch 112/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.2082 - learning_rate: 0.0010
# Epoch 113/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.2101 - learning_rate: 0.0010
# Epoch 114/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.2120 - learning_rate: 0.0010
# Epoch 115/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.2138 - learning_rate: 0.0010
# Epoch 116/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.2156 - learning_rate: 0.0010
# Epoch 117/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: -0.2174 - learning_rate: 0.0010
# Epoch 118/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.2192 - learning_rate: 0.0010
# Epoch 119/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.2210 - learning_rate: 0.0010
# Epoch 120/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.2227 - learning_rate: 0.0010
# Epoch 121/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.2245 - learning_rate: 0.0010
# Epoch 122/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.2262 - learning_rate: 0.0010
# Epoch 123/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.2279 - learning_rate: 0.0010
# Epoch 124/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.2295 - learning_rate: 0.0010
# Epoch 125/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.2312 - learning_rate: 0.0010
# Epoch 126/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.2328 - learning_rate: 0.0010
# Epoch 127/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.2345 - learning_rate: 0.0010
# Epoch 128/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.2361 - learning_rate: 0.0010
# Epoch 129/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.2377 - learning_rate: 0.0010
# Epoch 130/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.2393 - learning_rate: 0.0010
# Epoch 131/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.2409 - learning_rate: 0.0010
# Epoch 132/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.2424 - learning_rate: 0.0010
# Epoch 133/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.2440 - learning_rate: 0.0010
# Epoch 134/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.2455 - learning_rate: 0.0010
# Epoch 135/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.2470 - learning_rate: 0.0010
# Epoch 136/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.2485 - learning_rate: 0.0010
# Epoch 137/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.2500 - learning_rate: 0.0010
# Epoch 138/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.2515 - learning_rate: 0.0010
# Epoch 139/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.2530 - learning_rate: 0.0010
# Epoch 140/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.2545 - learning_rate: 0.0010
# Epoch 141/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.2559 - learning_rate: 0.0010
# Epoch 142/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.2574 - learning_rate: 0.0010
# Epoch 143/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.2588 - learning_rate: 0.0010
# Epoch 144/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.2602 - learning_rate: 0.0010
# Epoch 145/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.2617 - learning_rate: 0.0010
# Epoch 146/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.2631 - learning_rate: 0.0010
# Epoch 147/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.2645 - learning_rate: 0.0010
# Epoch 148/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.2659 - learning_rate: 0.0010
# Epoch 149/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -0.2673 - learning_rate: 0.0010
# Epoch 150/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.2687 - learning_rate: 0.0010
# Epoch 151/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: -0.2701 - learning_rate: 0.0010
# Epoch 152/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -0.2715 - learning_rate: 0.0010
# Epoch 153/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.2728 - learning_rate: 0.0010
# Epoch 154/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.2742 - learning_rate: 0.0010
# Epoch 155/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.2756 - learning_rate: 0.0010
# Epoch 156/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: -0.2770 - learning_rate: 0.0010
# Epoch 157/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.2783 - learning_rate: 0.0010
# Epoch 158/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.2797 - learning_rate: 0.0010
# Epoch 159/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.2811 - learning_rate: 0.0010
# Epoch 160/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.2825 - learning_rate: 0.0010
# Epoch 161/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.2838 - learning_rate: 0.0010
# Epoch 162/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.2852 - learning_rate: 0.0010
# Epoch 163/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.2866 - learning_rate: 0.0010
# Epoch 164/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.2880 - learning_rate: 0.0010
# Epoch 165/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.2894 - learning_rate: 0.0010
# Epoch 166/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.2908 - learning_rate: 0.0010
# Epoch 167/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.2923 - learning_rate: 0.0010
# Epoch 168/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.2937 - learning_rate: 0.0010
# Epoch 169/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.2951 - learning_rate: 0.0010
# Epoch 170/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -0.2966 - learning_rate: 0.0010
# Epoch 171/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.2981 - learning_rate: 0.0010
# Epoch 172/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.2996 - learning_rate: 0.0010
# Epoch 173/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.3011 - learning_rate: 0.0010
# Epoch 174/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.3026 - learning_rate: 0.0010
# Epoch 175/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: -0.3042 - learning_rate: 0.0010
# Epoch 176/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.3057 - learning_rate: 0.0010
# Epoch 177/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.3074 - learning_rate: 0.0010
# Epoch 178/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: -0.3090 - learning_rate: 0.0010
# Epoch 179/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.3107 - learning_rate: 0.0010
# Epoch 180/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.3124 - learning_rate: 0.0010
# Epoch 181/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -0.3141 - learning_rate: 0.0010
# Epoch 182/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -0.3159 - learning_rate: 0.0010
# Epoch 183/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.3177 - learning_rate: 0.0010
# Epoch 184/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.3196 - learning_rate: 0.0010
# Epoch 185/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.3215 - learning_rate: 0.0010
# Epoch 186/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -0.3235 - learning_rate: 0.0010
# Epoch 187/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.3255 - learning_rate: 0.0010
# Epoch 188/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.3276 - learning_rate: 0.0010
# Epoch 189/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: -0.3298 - learning_rate: 0.0010
# Epoch 190/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.3320 - learning_rate: 0.0010
# Epoch 191/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.3343 - learning_rate: 0.0010
# Epoch 192/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.3366 - learning_rate: 0.0010
# Epoch 193/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.3390 - learning_rate: 0.0010
# Epoch 194/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: -0.3415 - learning_rate: 0.0010
# Epoch 195/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.3441 - learning_rate: 0.0010
# Epoch 196/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -0.3467 - learning_rate: 0.0010
# Epoch 197/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.3495 - learning_rate: 0.0010
# Epoch 198/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.3523 - learning_rate: 0.0010
# Epoch 199/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.3551 - learning_rate: 0.0010
# Epoch 200/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: -0.3581 - learning_rate: 0.0010
# Epoch 201/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.3611 - learning_rate: 0.0010
# Epoch 202/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.3641 - learning_rate: 0.0010
# Epoch 203/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -0.3672 - learning_rate: 0.0010
# Epoch 204/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.3704 - learning_rate: 0.0010
# Epoch 205/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.3736 - learning_rate: 0.0010
# Epoch 206/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.3768 - learning_rate: 0.0010
# Epoch 207/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.3801 - learning_rate: 0.0010
# Epoch 208/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.3834 - learning_rate: 0.0010
# Epoch 209/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.3867 - learning_rate: 0.0010
# Epoch 210/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.3900 - learning_rate: 0.0010
# Epoch 211/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.3933 - learning_rate: 0.0010
# Epoch 212/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.3967 - learning_rate: 0.0010
# Epoch 213/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.4000 - learning_rate: 0.0010
# Epoch 214/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.4033 - learning_rate: 0.0010
# Epoch 215/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.4067 - learning_rate: 0.0010
# Epoch 216/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.4100 - learning_rate: 0.0010
# Epoch 217/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.4133 - learning_rate: 0.0010
# Epoch 218/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.4167 - learning_rate: 0.0010
# Epoch 219/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.4201 - learning_rate: 0.0010
# Epoch 220/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.4235 - learning_rate: 0.0010
# Epoch 221/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.4269 - learning_rate: 0.0010
# Epoch 222/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.4303 - learning_rate: 0.0010
# Epoch 223/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.4337 - learning_rate: 0.0010
# Epoch 224/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.4371 - learning_rate: 0.0010
# Epoch 225/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.4405 - learning_rate: 0.0010
# Epoch 226/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.4439 - learning_rate: 0.0010
# Epoch 227/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.4472 - learning_rate: 0.0010
# Epoch 228/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.4506 - learning_rate: 0.0010
# Epoch 229/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.4539 - learning_rate: 0.0010
# Epoch 230/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.4573 - learning_rate: 0.0010
# Epoch 231/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.4606 - learning_rate: 0.0010
# Epoch 232/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.4638 - learning_rate: 0.0010
# Epoch 233/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.4671 - learning_rate: 0.0010
# Epoch 234/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.4703 - learning_rate: 0.0010
# Epoch 235/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.4735 - learning_rate: 0.0010
# Epoch 236/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.4767 - learning_rate: 0.0010
# Epoch 237/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -0.4799 - learning_rate: 0.0010
# Epoch 238/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.4830 - learning_rate: 0.0010
# Epoch 239/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.4861 - learning_rate: 0.0010
# Epoch 240/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.4892 - learning_rate: 0.0010
# Epoch 241/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.4923 - learning_rate: 0.0010
# Epoch 242/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.4953 - learning_rate: 0.0010
# Epoch 243/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.4982 - learning_rate: 0.0010
# Epoch 244/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: -0.5012 - learning_rate: 0.0010
# Epoch 245/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.5041 - learning_rate: 0.0010
# Epoch 246/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.5069 - learning_rate: 0.0010
# Epoch 247/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.5097 - learning_rate: 0.0010
# Epoch 248/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.5124 - learning_rate: 0.0010
# Epoch 249/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.5151 - learning_rate: 0.0010
# Epoch 250/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.5178 - learning_rate: 0.0010
# Epoch 251/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.5204 - learning_rate: 0.0010
# Epoch 252/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.5229 - learning_rate: 0.0010
# Epoch 253/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.5254 - learning_rate: 0.0010
# Epoch 254/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.5279 - learning_rate: 0.0010
# Epoch 255/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.5303 - learning_rate: 0.0010
# Epoch 256/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.5327 - learning_rate: 0.0010
# Epoch 257/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.5350 - learning_rate: 0.0010
# Epoch 258/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.5373 - learning_rate: 0.0010
# Epoch 259/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.5396 - learning_rate: 0.0010
# Epoch 260/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.5418 - learning_rate: 0.0010
# Epoch 261/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -0.5441 - learning_rate: 0.0010
# Epoch 262/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.5462 - learning_rate: 0.0010
# Epoch 263/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.5484 - learning_rate: 0.0010
# Epoch 264/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.5505 - learning_rate: 0.0010
# Epoch 265/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.5526 - learning_rate: 0.0010
# Epoch 266/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.5547 - learning_rate: 0.0010
# Epoch 267/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.5567 - learning_rate: 0.0010
# Epoch 268/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.5587 - learning_rate: 0.0010
# Epoch 269/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.5607 - learning_rate: 0.0010
# Epoch 270/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.5627 - learning_rate: 0.0010
# Epoch 271/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.5646 - learning_rate: 0.0010
# Epoch 272/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.5666 - learning_rate: 0.0010
# Epoch 273/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.5685 - learning_rate: 0.0010
# Epoch 274/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.5704 - learning_rate: 0.0010
# Epoch 275/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.5723 - learning_rate: 0.0010
# Epoch 276/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -0.5741 - learning_rate: 0.0010
# Epoch 277/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.5760 - learning_rate: 0.0010
# Epoch 278/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.5778 - learning_rate: 0.0010
# Epoch 279/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.5796 - learning_rate: 0.0010
# Epoch 280/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.5814 - learning_rate: 0.0010
# Epoch 281/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.5832 - learning_rate: 0.0010
# Epoch 282/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.5850 - learning_rate: 0.0010
# Epoch 283/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.5868 - learning_rate: 0.0010
# Epoch 284/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.5885 - learning_rate: 0.0010
# Epoch 285/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.5903 - learning_rate: 0.0010
# Epoch 286/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.5920 - learning_rate: 0.0010
# Epoch 287/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.5938 - learning_rate: 0.0010
# Epoch 288/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.5955 - learning_rate: 0.0010
# Epoch 289/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: -0.5972 - learning_rate: 0.0010
# Epoch 290/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.5989 - learning_rate: 0.0010
# Epoch 291/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.6006 - learning_rate: 0.0010
# Epoch 292/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.6022 - learning_rate: 0.0010
# Epoch 293/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.6039 - learning_rate: 0.0010
# Epoch 294/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.6056 - learning_rate: 0.0010
# Epoch 295/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.6072 - learning_rate: 0.0010
# Epoch 296/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.6088 - learning_rate: 0.0010
# Epoch 297/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.6105 - learning_rate: 0.0010
# Epoch 298/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.6121 - learning_rate: 0.0010
# Epoch 299/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.6137 - learning_rate: 0.0010
# Epoch 300/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.6153 - learning_rate: 0.0010
# Epoch 301/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.6169 - learning_rate: 0.0010
# Epoch 302/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.6184 - learning_rate: 0.0010
# Epoch 303/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.6200 - learning_rate: 0.0010
# Epoch 304/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -0.6216 - learning_rate: 0.0010
# Epoch 305/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.6231 - learning_rate: 0.0010
# Epoch 306/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.6246 - learning_rate: 0.0010
# Epoch 307/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.6261 - learning_rate: 0.0010
# Epoch 308/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.6277 - learning_rate: 0.0010
# Epoch 309/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.6292 - learning_rate: 0.0010
# Epoch 310/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.6306 - learning_rate: 0.0010
# Epoch 311/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.6321 - learning_rate: 0.0010
# Epoch 312/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.6336 - learning_rate: 0.0010
# Epoch 313/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.6350 - learning_rate: 0.0010
# Epoch 314/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.6365 - learning_rate: 0.0010
# Epoch 315/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.6379 - learning_rate: 0.0010
# Epoch 316/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.6393 - learning_rate: 0.0010
# Epoch 317/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.6408 - learning_rate: 0.0010
# Epoch 318/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.6422 - learning_rate: 0.0010
# Epoch 319/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.6436 - learning_rate: 0.0010
# Epoch 320/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.6449 - learning_rate: 0.0010
# Epoch 321/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.6463 - learning_rate: 0.0010
# Epoch 322/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.6477 - learning_rate: 0.0010
# Epoch 323/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.6490 - learning_rate: 0.0010
# Epoch 324/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.6504 - learning_rate: 0.0010
# Epoch 325/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.6517 - learning_rate: 0.0010
# Epoch 326/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.6531 - learning_rate: 0.0010
# Epoch 327/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.6544 - learning_rate: 0.0010
# Epoch 328/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.6557 - learning_rate: 0.0010
# Epoch 329/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.6570 - learning_rate: 0.0010
# Epoch 330/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.6583 - learning_rate: 0.0010
# Epoch 331/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.6596 - learning_rate: 0.0010
# Epoch 332/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.6609 - learning_rate: 0.0010
# Epoch 333/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.6622 - learning_rate: 0.0010
# Epoch 334/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.6635 - learning_rate: 0.0010
# Epoch 335/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.6647 - learning_rate: 0.0010
# Epoch 336/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.6660 - learning_rate: 0.0010
# Epoch 337/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.6672 - learning_rate: 0.0010
# Epoch 338/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.6685 - learning_rate: 0.0010
# Epoch 339/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.6697 - learning_rate: 0.0010
# Epoch 340/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.6710 - learning_rate: 0.0010
# Epoch 341/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.6722 - learning_rate: 0.0010
# Epoch 342/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.6734 - learning_rate: 0.0010
# Epoch 343/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.6746 - learning_rate: 0.0010
# Epoch 344/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.6758 - learning_rate: 0.0010
# Epoch 345/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.6771 - learning_rate: 0.0010
# Epoch 346/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.6783 - learning_rate: 0.0010
# Epoch 347/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.6795 - learning_rate: 0.0010
# Epoch 348/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.6806 - learning_rate: 0.0010
# Epoch 349/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.6818 - learning_rate: 0.0010
# Epoch 350/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: -0.6830 - learning_rate: 0.0010
# Epoch 351/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.6842 - learning_rate: 0.0010
# Epoch 352/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.6854 - learning_rate: 0.0010
# Epoch 353/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.6865 - learning_rate: 0.0010
# Epoch 354/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.6877 - learning_rate: 0.0010
# Epoch 355/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.6888 - learning_rate: 0.0010
# Epoch 356/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.6900 - learning_rate: 0.0010
# Epoch 357/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.6911 - learning_rate: 0.0010
# Epoch 358/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.6923 - learning_rate: 0.0010
# Epoch 359/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.6934 - learning_rate: 0.0010
# Epoch 360/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.6945 - learning_rate: 0.0010
# Epoch 361/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.6956 - learning_rate: 0.0010
# Epoch 362/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.6967 - learning_rate: 0.0010
# Epoch 363/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.6978 - learning_rate: 0.0010
# Epoch 364/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -0.6989 - learning_rate: 0.0010
# Epoch 365/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7000 - learning_rate: 0.0010
# Epoch 366/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.7011 - learning_rate: 0.0010
# Epoch 367/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -0.7021 - learning_rate: 0.0010
# Epoch 368/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7032 - learning_rate: 0.0010
# Epoch 369/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.7043 - learning_rate: 0.0010
# Epoch 370/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.7053 - learning_rate: 0.0010
# Epoch 371/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.7063 - learning_rate: 0.0010
# Epoch 372/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7073 - learning_rate: 0.0010
# Epoch 373/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.7084 - learning_rate: 0.0010
# Epoch 374/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.7094 - learning_rate: 0.0010
# Epoch 375/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7104 - learning_rate: 0.0010
# Epoch 376/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7113 - learning_rate: 0.0010
# Epoch 377/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7123 - learning_rate: 0.0010
# Epoch 378/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7133 - learning_rate: 0.0010
# Epoch 379/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.7142 - learning_rate: 0.0010
# Epoch 380/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.7152 - learning_rate: 0.0010
# Epoch 381/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.7161 - learning_rate: 0.0010
# Epoch 382/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7170 - learning_rate: 0.0010
# Epoch 383/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7179 - learning_rate: 0.0010
# Epoch 384/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -0.7188 - learning_rate: 0.0010
# Epoch 385/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7197 - learning_rate: 0.0010
# Epoch 386/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7206 - learning_rate: 0.0010
# Epoch 387/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7215 - learning_rate: 0.0010
# Epoch 388/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: -0.7223 - learning_rate: 0.0010
# Epoch 389/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7232 - learning_rate: 0.0010
# Epoch 390/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7240 - learning_rate: 0.0010
# Epoch 391/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7249 - learning_rate: 0.0010
# Epoch 392/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.7257 - learning_rate: 0.0010
# Epoch 393/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.7265 - learning_rate: 0.0010
# Epoch 394/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.7273 - learning_rate: 0.0010
# Epoch 395/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -0.7281 - learning_rate: 0.0010
# Epoch 396/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.7289 - learning_rate: 0.0010
# Epoch 397/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7297 - learning_rate: 0.0010
# Epoch 398/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.7305 - learning_rate: 0.0010
# Epoch 399/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.7313 - learning_rate: 0.0010
# Epoch 400/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.7320 - learning_rate: 0.0010
# Epoch 401/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7328 - learning_rate: 0.0010
# Epoch 402/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.7335 - learning_rate: 0.0010
# Epoch 403/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7343 - learning_rate: 0.0010
# Epoch 404/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7350 - learning_rate: 0.0010
# Epoch 405/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7357 - learning_rate: 0.0010
# Epoch 406/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7365 - learning_rate: 0.0010
# Epoch 407/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7372 - learning_rate: 0.0010
# Epoch 408/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7379 - learning_rate: 0.0010
# Epoch 409/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7386 - learning_rate: 0.0010
# Epoch 410/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7393 - learning_rate: 0.0010
# Epoch 411/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.7400 - learning_rate: 0.0010
# Epoch 412/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.7407 - learning_rate: 0.0010
# Epoch 413/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.7414 - learning_rate: 0.0010
# Epoch 414/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7421 - learning_rate: 0.0010
# Epoch 415/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.7427 - learning_rate: 0.0010
# Epoch 416/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7434 - learning_rate: 0.0010
# Epoch 417/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7441 - learning_rate: 0.0010
# Epoch 418/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.7448 - learning_rate: 0.0010
# Epoch 419/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.7454 - learning_rate: 0.0010
# Epoch 420/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7461 - learning_rate: 0.0010
# Epoch 421/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7467 - learning_rate: 0.0010
# Epoch 422/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7474 - learning_rate: 0.0010
# Epoch 423/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7480 - learning_rate: 0.0010
# Epoch 424/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: -0.7487 - learning_rate: 0.0010
# Epoch 425/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.7493 - learning_rate: 0.0010
# Epoch 426/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7500 - learning_rate: 0.0010
# Epoch 427/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.7506 - learning_rate: 0.0010
# Epoch 428/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.7513 - learning_rate: 0.0010
# Epoch 429/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7519 - learning_rate: 0.0010
# Epoch 430/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7525 - learning_rate: 0.0010
# Epoch 431/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.7532 - learning_rate: 0.0010
# Epoch 432/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7538 - learning_rate: 0.0010
# Epoch 433/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.7544 - learning_rate: 0.0010
# Epoch 434/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7550 - learning_rate: 0.0010
# Epoch 435/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.7557 - learning_rate: 0.0010
# Epoch 436/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7563 - learning_rate: 0.0010
# Epoch 437/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7569 - learning_rate: 0.0010
# Epoch 438/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.7575 - learning_rate: 0.0010
# Epoch 439/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.7582 - learning_rate: 0.0010
# Epoch 440/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.7588 - learning_rate: 0.0010
# Epoch 441/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.7594 - learning_rate: 0.0010
# Epoch 442/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7600 - learning_rate: 0.0010
# Epoch 443/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7606 - learning_rate: 0.0010
# Epoch 444/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.7612 - learning_rate: 0.0010
# Epoch 445/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.7619 - learning_rate: 0.0010
# Epoch 446/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7625 - learning_rate: 0.0010
# Epoch 447/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7631 - learning_rate: 0.0010
# Epoch 448/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.7637 - learning_rate: 0.0010
# Epoch 449/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.7643 - learning_rate: 0.0010
# Epoch 450/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.7649 - learning_rate: 0.0010
# Epoch 451/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7655 - learning_rate: 0.0010
# Epoch 452/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.7661 - learning_rate: 0.0010
# Epoch 453/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7667 - learning_rate: 0.0010
# Epoch 454/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7673 - learning_rate: 0.0010
# Epoch 455/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7679 - learning_rate: 0.0010
# Epoch 456/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7685 - learning_rate: 0.0010
# Epoch 457/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.7692 - learning_rate: 0.0010
# Epoch 458/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7698 - learning_rate: 0.0010
# Epoch 459/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7704 - learning_rate: 0.0010
# Epoch 460/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7710 - learning_rate: 0.0010
# Epoch 461/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7716 - learning_rate: 0.0010
# Epoch 462/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.7722 - learning_rate: 0.0010
# Epoch 463/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7728 - learning_rate: 0.0010
# Epoch 464/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.7734 - learning_rate: 0.0010
# Epoch 465/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.7740 - learning_rate: 0.0010
# Epoch 466/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7746 - learning_rate: 0.0010
# Epoch 467/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.7752 - learning_rate: 0.0010
# Epoch 468/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7758 - learning_rate: 0.0010
# Epoch 469/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.7764 - learning_rate: 0.0010
# Epoch 470/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7770 - learning_rate: 0.0010
# Epoch 471/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.7776 - learning_rate: 0.0010
# Epoch 472/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.7782 - learning_rate: 0.0010
# Epoch 473/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7789 - learning_rate: 0.0010
# Epoch 474/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.7795 - learning_rate: 0.0010
# Epoch 475/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.7801 - learning_rate: 0.0010
# Epoch 476/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.7807 - learning_rate: 0.0010
# Epoch 477/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.7813 - learning_rate: 0.0010
# Epoch 478/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7819 - learning_rate: 0.0010
# Epoch 479/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7825 - learning_rate: 0.0010
# Epoch 480/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.7831 - learning_rate: 0.0010
# Epoch 481/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.7838 - learning_rate: 0.0010
# Epoch 482/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7844 - learning_rate: 0.0010
# Epoch 483/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.7850 - learning_rate: 0.0010
# Epoch 484/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.7856 - learning_rate: 0.0010
# Epoch 485/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.7862 - learning_rate: 0.0010
# Epoch 486/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7869 - learning_rate: 0.0010
# Epoch 487/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.7875 - learning_rate: 0.0010
# Epoch 488/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7881 - learning_rate: 0.0010
# Epoch 489/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7887 - learning_rate: 0.0010
# Epoch 490/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -0.7894 - learning_rate: 0.0010
# Epoch 491/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7900 - learning_rate: 0.0010
# Epoch 492/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7906 - learning_rate: 0.0010
# Epoch 493/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7913 - learning_rate: 0.0010
# Epoch 494/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7919 - learning_rate: 0.0010
# Epoch 495/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7926 - learning_rate: 0.0010
# Epoch 496/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.7932 - learning_rate: 0.0010
# Epoch 497/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.7938 - learning_rate: 0.0010
# Epoch 498/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7945 - learning_rate: 0.0010
# Epoch 499/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7951 - learning_rate: 0.0010
# Epoch 500/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.7958 - learning_rate: 0.0010
# Epoch 501/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7964 - learning_rate: 0.0010
# Epoch 502/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -0.7971 - learning_rate: 0.0010
# Epoch 503/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7978 - learning_rate: 0.0010
# Epoch 504/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7984 - learning_rate: 0.0010
# Epoch 505/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.7991 - learning_rate: 0.0010
# Epoch 506/5000
# ...
# Epoch 4833/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: -1.3681 - learning_rate: 0.0010
# Epoch 4834/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -1.4756 - learning_rate: 0.0010
# Epoch 4835/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.5386 - learning_rate: 0.0010
# Epoch 4836/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -1.5788 - learning_rate: 0.0010
# Epoch 4837/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -1.6456 - learning_rate: 0.0010
# Epoch 4838/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: -1.6454 - learning_rate: 0.0010
# Epoch 4839/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -1.6397 - learning_rate: 0.0010
# Epoch 4840/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.6494 - learning_rate: 0.0010
# Epoch 4841/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -1.6509 - learning_rate: 0.0010
# Epoch 4842/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.6470 - learning_rate: 0.0010
# Epoch 4843/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -1.6481 - learning_rate: 0.0010
# Epoch 4844/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -1.6543 - learning_rate: 0.0010
# Epoch 4845/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.6642 - learning_rate: 0.0010
# Epoch 4846/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -1.6691 - learning_rate: 0.0010
# Epoch 4847/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: -1.6306 - learning_rate: 0.0010
# Epoch 4848/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.5871 - learning_rate: 0.0010
# Epoch 4849/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.5535 - learning_rate: 0.0010
# Epoch 4850/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -1.4320 - learning_rate: 0.0010
# Epoch 4851/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.2648 - learning_rate: 0.0010
# Epoch 4852/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: -1.4347 - learning_rate: 0.0010
# Epoch 4853/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.5498 - learning_rate: 0.0010
# Epoch 4854/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -1.5575 - learning_rate: 0.0010
# Epoch 4855/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -1.6301 - learning_rate: 0.0010
# Epoch 4856/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.6247 - learning_rate: 0.0010
# Epoch 4857/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: -1.6249 - learning_rate: 0.0010
# Epoch 4858/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.6476 - learning_rate: 0.0010
# Epoch 4859/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -1.6577 - learning_rate: 0.0010
# Epoch 4860/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -1.6371 - learning_rate: 0.0010
# Epoch 4861/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -1.6023 - learning_rate: 0.0010
# Epoch 4862/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -1.5775 - learning_rate: 0.0010
# Epoch 4863/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -1.6036 - learning_rate: 0.0010
# Epoch 4864/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -1.6063 - learning_rate: 0.0010
# Epoch 4865/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -1.4858 - learning_rate: 0.0010
# Epoch 4866/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.3825 - learning_rate: 0.0010
# Epoch 4867/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.4230 - learning_rate: 0.0010
# Epoch 4868/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.5046 - learning_rate: 0.0010
# Epoch 4869/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: -1.5706 - learning_rate: 0.0010
# Epoch 4870/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.6072 - learning_rate: 0.0010
# Epoch 4871/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.6563 - learning_rate: 0.0010
# Epoch 4872/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.6646 - learning_rate: 0.0010
# Epoch 4873/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.6599 - learning_rate: 0.0010
# Epoch 4874/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -1.6551 - learning_rate: 0.0010
# Epoch 4875/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: -1.6477 - learning_rate: 0.0010
# Epoch 4876/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.6549 - learning_rate: 0.0010
# Epoch 4877/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.6351 - learning_rate: 0.0010
# Epoch 4878/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -1.5608 - learning_rate: 0.0010
# Epoch 4879/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -1.4394 - learning_rate: 0.0010
# Epoch 4880/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -1.4382 - learning_rate: 0.0010
# Epoch 4881/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -1.2481 - learning_rate: 0.0010
# Epoch 4882/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -1.4256 - learning_rate: 0.0010
# Epoch 4883/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.5541 - learning_rate: 0.0010
# Epoch 4884/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: -1.6109 - learning_rate: 0.0010
# Epoch 4885/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.6030 - learning_rate: 0.0010
# Epoch 4886/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -1.5788 - learning_rate: 0.0010
# Epoch 4887/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.6157 - learning_rate: 0.0010
# Epoch 4888/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -1.6504 - learning_rate: 0.0010
# Epoch 4889/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -1.6297 - learning_rate: 0.0010
# Epoch 4890/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -1.6188 - learning_rate: 0.0010
# Epoch 4891/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.6417 - learning_rate: 0.0010
# Epoch 4892/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.6460 - learning_rate: 0.0010
# Epoch 4893/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -1.5842 - learning_rate: 0.0010
# Epoch 4894/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.5023 - learning_rate: 0.0010
# Epoch 4895/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: -1.5001 - learning_rate: 0.0010
# Epoch 4896/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -1.5289 - learning_rate: 0.0010
# Epoch 4897/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.3999 - learning_rate: 0.0010
# Epoch 4898/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.5262 - learning_rate: 0.0010
# Epoch 4899/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -1.5656 - learning_rate: 0.0010
# Epoch 4900/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.5740 - learning_rate: 0.0010
# Epoch 4901/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -1.6179 - learning_rate: 0.0010
# Epoch 4902/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -1.6383 - learning_rate: 0.0010
# Epoch 4903/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.6117 - learning_rate: 0.0010
# Epoch 4904/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -1.6085 - learning_rate: 0.0010
# Epoch 4905/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -1.6363 - learning_rate: 0.0010
# Epoch 4906/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -1.6395 - learning_rate: 0.0010
# Epoch 4907/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.6073 - learning_rate: 0.0010
# Epoch 4908/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.5812 - learning_rate: 0.0010
# Epoch 4909/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -1.6021 - learning_rate: 0.0010
# Epoch 4910/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -1.6382 - learning_rate: 0.0010
# Epoch 4911/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -1.5920 - learning_rate: 0.0010
# Epoch 4912/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.5038 - learning_rate: 0.0010
# Epoch 4913/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: -1.5005 - learning_rate: 0.0010
# Epoch 4914/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -1.5255 - learning_rate: 0.0010
# Epoch 4915/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.5389 - learning_rate: 0.0010
# Epoch 4916/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.5462 - learning_rate: 0.0010
# Epoch 4917/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: -1.6068 - learning_rate: 0.0010
# Epoch 4918/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: -1.6419 - learning_rate: 0.0010
# Epoch 4919/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -1.6372 - learning_rate: 0.0010
# Epoch 4920/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: -1.6520 - learning_rate: 0.0010
# Epoch 4921/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -1.6551 - learning_rate: 0.0010
# Epoch 4922/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: -1.6392 - learning_rate: 0.0010
# Epoch 4923/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -1.6457 - learning_rate: 0.0010
# Epoch 4924/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.6432 - learning_rate: 0.0010
# Epoch 4925/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.6264 - learning_rate: 0.0010
# Epoch 4926/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.5519 - learning_rate: 0.0010
# Epoch 4927/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.4486 - learning_rate: 0.0010
# Epoch 4928/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.5012 - learning_rate: 0.0010
# Epoch 4929/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -1.4460 - learning_rate: 0.0010
# Epoch 4930/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -1.4499 - learning_rate: 0.0010
# Epoch 4931/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -1.5951 - learning_rate: 0.0010
# Epoch 4932/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -1.6274 - learning_rate: 0.0010
# Epoch 4933/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -1.6586 - learning_rate: 0.0010
# Epoch 4934/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -1.6641 - learning_rate: 0.0010
# Epoch 4935/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -1.6483 - learning_rate: 0.0010
# Epoch 4936/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.6213 - learning_rate: 0.0010
# Epoch 4937/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: -1.6207 - learning_rate: 0.0010
# Epoch 4938/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.6527 - learning_rate: 0.0010
# Epoch 4939/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -1.6418 - learning_rate: 0.0010
# Epoch 4940/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -1.5815 - learning_rate: 0.0010
# Epoch 4941/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: -1.5068 - learning_rate: 0.0010
# Epoch 4942/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -1.5037 - learning_rate: 0.0010
# Epoch 4943/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -1.5343 - learning_rate: 0.0010
# Epoch 4944/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: -1.5399 - learning_rate: 0.0010
# Epoch 4945/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: -1.5056 - learning_rate: 0.0010
# Epoch 4946/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: -1.5566 - learning_rate: 0.0010
# Epoch 4947/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.6366 - learning_rate: 0.0010
# Epoch 4948/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: -1.6193 - learning_rate: 0.0010
# Epoch 4949/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -1.6306 - learning_rate: 0.0010
# Epoch 4950/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.6597 - learning_rate: 0.0010
# Epoch 4951/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.6424 - learning_rate: 0.0010
# Epoch 4952/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: -1.6241 - learning_rate: 0.0010
# Epoch 4953/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.6241 - learning_rate: 0.0010
# Epoch 4954/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: -1.6561 - learning_rate: 0.0010
# Epoch 4955/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -1.6741 - learning_rate: 0.0010
# Epoch 4956/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -1.6702 - learning_rate: 0.0010
# Epoch 4957/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -1.6348 - learning_rate: 0.0010
# Epoch 4958/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -1.6118 - learning_rate: 0.0010
# Epoch 4959/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.5288 - learning_rate: 0.0010
# Epoch 4960/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.2240 - learning_rate: 0.0010
# Epoch 4961/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: -1.2852 - learning_rate: 0.0010
# Epoch 4962/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -1.4748 - learning_rate: 0.0010
# Epoch 4963/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.5567 - learning_rate: 0.0010
# Epoch 4964/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -1.5972 - learning_rate: 0.0010
# Epoch 4965/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -1.6305 - learning_rate: 0.0010
# Epoch 4966/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -1.6591 - learning_rate: 0.0010
# Epoch 4967/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: -1.6634 - learning_rate: 0.0010
# Epoch 4968/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.6632 - learning_rate: 0.0010
# Epoch 4969/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -1.6748 - learning_rate: 0.0010
# Epoch 4970/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -1.6835 - learning_rate: 0.0010
# Epoch 4971/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: -1.6694 - learning_rate: 0.0010
# Epoch 4972/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: -1.6227 - learning_rate: 0.0010
# Epoch 4973/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.5263 - learning_rate: 0.0010
# Epoch 4974/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.3936 - learning_rate: 0.0010
# Epoch 4975/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: -1.4815 - learning_rate: 0.0010
# Epoch 4976/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: -1.3601 - learning_rate: 0.0010
# Epoch 4977/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -1.5225 - learning_rate: 0.0010
# Epoch 4978/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: -1.5732 - learning_rate: 0.0010
# Epoch 4979/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: -1.6368 - learning_rate: 0.0010
# Epoch 4980/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.6566 - learning_rate: 0.0010
# Epoch 4981/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.6303 - learning_rate: 0.0010
# Epoch 4982/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.5836 - learning_rate: 0.0010
# Epoch 4983/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -1.6156 - learning_rate: 0.0010
# Epoch 4984/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.6467 - learning_rate: 0.0010
# Epoch 4985/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -1.5353 - learning_rate: 0.0010
# Epoch 4986/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -1.5206 - learning_rate: 0.0010
# Epoch 4987/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.6079 - learning_rate: 0.0010
# Epoch 4988/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.5540 - learning_rate: 0.0010
# Epoch 4989/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.5509 - learning_rate: 0.0010
# Epoch 4990/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.6275 - learning_rate: 0.0010
# Epoch 4991/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.5842 - learning_rate: 0.0010
# Epoch 4992/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -1.5613 - learning_rate: 0.0010
# Epoch 4993/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -1.6218 - learning_rate: 0.0010
# Epoch 4994/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: -1.5974 - learning_rate: 0.0010
# Epoch 4995/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -1.5428 - learning_rate: 0.0010
# Epoch 4996/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -1.5991 - learning_rate: 0.0010
# Epoch 4997/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -1.6067 - learning_rate: 0.0010
# Epoch 4998/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: -1.5238 - learning_rate: 0.0010
# Epoch 4999/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -1.5926 - learning_rate: 0.0010
# Epoch 5000/5000
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -1.6057 - learning_rate: 0.0010

# %% [markdown]
# ## Evaluate Test Data

# %%
# Make predictions with uncertainty
mean_pred, std_pred = model.predict_with_uncertainty(X_test)

# Calculate confidence intervals
confidence_95 = 1.96 * std_pred
lower_bound = mean_pred - confidence_95
upper_bound = mean_pred + confidence_95

# %%
y_test.shape
# Out:
# (162,)

# %%
rmse = root_mean_squared_error(y_test, mean_pred)

r2 = r2_score(y_test, mean_pred)

print(rmse)
print(r2)
# Out:
# 6.278691340890689
# 0.915585114011699

# %%
y_train_pred, train_var = model.predict_with_uncertainty(X_train)

# %% [markdown]
# ## Save Model and Results

# %%
filepath = '../model_evaluation/pickles/dnn_model'
model.save(filepath)
# Load model
loaded_model = HeteroscedasticDNN.load(filepath)
# Out:
# Model saved to ../model_evaluation/pickles/dnn_model
# Model is None: False

# %%
train_df = pd.DataFrame({
    'y_true': y_train.flatten(),
    'y_pred': y_train_pred.flatten(),
    'var_pred': train_var.flatten(),
    'is_train': 1
}, index=y_train_df.index)

test_df = pd.DataFrame({
    'y_true': y_test.flatten(),
    'y_pred': mean_pred.flatten(),
    'var_pred': std_pred.flatten(),
    'is_train': 0
}, index=y_test_df.index)

results = pd.concat([train_df, test_df])

full_results = n4_df['Glass Name'].to_frame().join(results, how='left')

full_results.to_csv('../results/regression/DNN_with_cr_results.csv')

# %%
import matplotlib.pyplot as plt

# Flatten arrays for plotting
y_true = y_test.flatten()
y_pred = mean_pred.flatten()
y_std = std_pred.flatten()

# Set axis limits to the same range
min_val = min(y_true.min(), y_pred.min())
max_val = max(y_true.max(), y_pred.max())

# Confidence intervals (z-scores for normal distribution)
conf_levels = {
    # "80%": 1.28,
    # "90%": 1.645,
    "95%": 1.96
}

plt.figure(figsize=(6, 6))
plt.plot([min_val, max_val], [min_val, max_val], 'r--', label='Ideal')

# Plot predictions with error bars for each confidence interval
for label, z in conf_levels.items():
    plt.errorbar(
        y_true, y_pred, yerr=z * y_std,
        fmt='o', alpha=0.4, label=f'Prediction ±{label} CI'
    )

plt.xlabel('True N4_NMR', fontsize=14)
plt.ylabel('Predicted N4_NMR', fontsize=14)
plt.title('Validation: Prediction with Confidence Intervals', fontsize=16)
plt.xlim(min_val, max_val)
plt.ylim(min_val, max_val)
# plt.xlim(-0.2, 1.0)
# plt.ylim(-0.2, 1.0)
plt.legend(loc='lower right', fontsize=12)
plt.grid(True)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()
plt.show()
